# %% [markdown]
# # Table of contents
#
# ## 01. Importing libraries
#
# ## 02. Importing data
#
# ## 03. Data wrangling
# ### 03.1 Dropping columns
# ### 03.2 Renaming columns
# ### 03.3 Changing data types
# ### 03.4 Transposing data
#
# ## 04. Creating a data dictionary
#
# ## 05. Subsetting
#
# ## 06. Task
# ### Step 06.2: Changing identifier variable in df_ords from numeric to suitable other format
# ### Step 06.3: Changing unintuitive name of variable in df_ords without overwriting data frame
# ### Step 06.4: Identifying the busiest hour for placing orders
# ### Step 06.5: Determining meaning behind a value of 4 in department_id column within df_prods using data dictionary
# ### Step 06.6: Creating subset containing only breakfast items
# ### Step 06.7: Finding all observations in df_prods that include items from departments: alcohol, deli, beverages, and meat/seafood (dinner party items)
# ### Step 06.8: Count of rows in df_dinner_party_items
# ### Step 06.9: Extracting all information about user with user_id=1
# ### Step 06.10: Providing details about behaviour of user with user_id=1 (basic stats)
# ### Step 06.12: Exporting wrangled df_ords
# ### Step 06.13: Exporting wrangled dataframe on departments

# %% [markdown]
# # 01. Importing libraries

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Importing data

# %%
# Assigning path variable
path = r'/Users/DanielaDietmayr/Library/CloudStorage/OneDrive-Personal/2023-01-18 Instacart basket analysis'

# %%
# Defining list of necessary columns
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
# Importing orders data
df_ords = pd.read_csv(os.path.join(path, '02 Data', '01 Original data', 'orders.csv'), usecols = vars_list)

# %%
# Importing products data
df_prods = pd.read_csv(os.path.join(path, '02 Data', '01 Original data', 'products.csv'), index_col = False)

# %%
# Checking orders data import
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Checking products data import
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Redefining df_ords to include all columns
df_ords = pd.read_csv(os.path.join(path, '02 Data', '01 Original data', 'orders.csv'), index_col = False)

# %%
# Checking updated orders data import
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# # 03. Data wrangling

# %% [markdown]
# ## 03.1 Dropping columns

# %%
# Dropping column eval_set
df_ords = df_ords.drop(columns = ['eval_set'])

# %%
# Checking orders dataframe after dropping column eval_set
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Checking for missing values on column days_since_prior_order
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
# Checking purpose of argument
df_ords['days_since_prior_order'].value_counts(dropna = True)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
# Checking orders dataframe head for missing values
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## 03.2 Renaming columns

# %%
# Renaming column order_dow to order_day_of_the_week
df_ords.rename(columns = {'order_dow' : 'order_day_of_the_week'}, inplace = True)

# %%
# Checking new column name
df_ords.head()
# Out:
#    order_id  user_id  order_number  order_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                      2                  8
# 1   2398795        1             2                      3                  7
# 2    473747        1             3                      3                 12
# 3   2254736        1             4                      4                  7
# 4    431534        1             5                      4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## 03.3 Changing data types

# %%
# Changing data type of column order_id from integer to string
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
# Checking change of data type
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## 03.4 Transposing data

# %%
# Importing department data
df_dep = pd.read_csv(os.path.join(path, '02 Data', '01 Original data', 'departments.csv'), index_col = False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# Transposing department data
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Creating a new, transposed dataframe
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# Adding an index to the transposed dataframe
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Creating object for new header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# Creating new dataframe without wrong header
df_dep_t_new = df_dep_t[1:]

# %%
# Checking new dataframe without wrong header
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# Using object new_header as header in new dataframe
df_dep_t_new.columns = new_header

# %%
# Checking header in new dataframe
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %% [markdown]
# # 04. Creating a data dictionary

# %%
# Turning dataframe into data dictionary
data_dict = df_dep_t_new.to_dict ('index')

# %%
# Printing variable data_dict
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
# Recalling data on products
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Checking the meaining of a department_id of 19
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %% [markdown]
# # 05. Subsetting

# %%
# Output of all elements for which department_id == 19 is True
df_prods['department_id']=='19'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
# Wrapping indexing code in dataframe
df_prods [df_prods ['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
# Creating a dataframe for subset data on snacks
df_snacks = df_prods[df_prods['department_id']==19]

# %%
# Checking subset data
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
# Creating a subset with loc for one value
df_snacks_2 = df_prods.loc[df_prods['department_id']==19]

# %%
# Checking subset with loc for one value
df_snacks_2.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
# Creating a subset with loc for more than one value
df_snacksetc_3 = df_prods.loc[df_prods['department_id'].isin([19,20])]

# %%
# Checking subset with loc for more than one value
df_snacksetc_3.head(10)
# Out:
#     product_id                                   product_name  aisle_id  \
# 0            1                     Chocolate Sandwich Cookies        61
# 15          16                  Mint Chocolate Flavored Syrup       103
# 24          25        Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                  Nacho Cheese White Bean Chips       107
# 40          41    Organic Sourdough Einkorn Crackers Rosemary        78
# 48          49  Vegetarian Grain Meat Sausages Italian - 4 CT        14
# 55          56                     Healthy Pop Butter Popcorn        23
# 58          59           Medium Taqueria Style Chipotle Salsa        50
# 61          62        Premium Deli Oven Roasted Turkey Breast        96
# 73          74                Artisan Chick'n & Apple Sausage        14
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5
# ...

# %% [markdown]
# # 06. Task

# %% [markdown]
# ## Step 06.2: Changing identifier variable in df_ords from numeric to suitable other format

# %%
# Checking variables in df_ords
df_ords.head()
# Out:
#   order_id  user_id  order_number  order_day_of_the_week  order_hour_of_day  \
# 0  2539329        1             1                      2                  8
# 1  2398795        1             2                      3                  7
# 2   473747        1             3                      3                 12
# 3  2254736        1             4                      4                  7
# 4   431534        1             5                      4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Checking data types in df_ords
df_ords.dtypes
# Out:
# order_id                   object
# user_id                     int64
# order_number                int64
# order_day_of_the_week       int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# Changing data type for user_id
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
# Checking data types again
df_ords['user_id'].dtype
# Out:
# dtype('O')

# %% [markdown]
# ## Step 06.3: Changing unintuitive name of variable in df_ords without overwriting data frame

# %%
# Changing name of order_number to order_sequence_per_user
df_ords.rename(columns = {'order_number':'order_sequence_per_user'}, inplace=True)

# %%
# Checking renamed variable
df_ords.head()
# Out:
#   order_id user_id  order_sequence_per_user  order_day_of_the_week  \
# 0  2539329       1                        1                      2
# 1  2398795       1                        2                      3
# 2   473747       1                        3                      3
# 3  2254736       1                        4                      4
# 4   431534       1                        5                      4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %% [markdown]
# ## Step 06.4: Identifying the busiest hour for placing orders

# %%
# Identifying mode for order_hour_of_day
df_ords.mode(axis=0, numeric_only=False, dropna=False)
# Out:
#         order_id user_id  order_sequence_per_user  order_day_of_the_week  \
# 0              1  100142                      1.0                    0.0
# 1             10  100316                      2.0                    NaN
# 2            100  100325                      3.0                    NaN
# 3           1000   10046                      4.0                    NaN
# 4          10000  100514                      NaN                    NaN
# ...          ...     ...                      ...                    ...
# 3421078   999995     NaN                      NaN                    NaN
# 3421079   999996     NaN                      NaN                    NaN
# 3421080   999997     NaN                      NaN                    NaN
# 3421081   999998     NaN                      NaN                    NaN
# 3421082   999999     NaN                      NaN                    NaN
#
#          order_hour_of_day  days_since_prior_order
# ...

# %%
# Double-checking through counts of values in order_hour_of_day
df_ords['order_hour_of_day'].value_counts(dropna=False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# ## Step 06.5: Determining meaning behind a value of 4 in department_id column within df_prods using data dictionary

# %%
# Deciphering department_id value 4
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %% [markdown]
# ## Step 06.6: Creating subset containing only breakfast items

# %%
# Creating a subset with only breakfast items, department_id 14
df_breakfast_items = df_prods[df_prods['department_id']==14]

# %%
# Checking subset on breakfast items
df_breakfast_items.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %% [markdown]
# ## Step 06.7: Finding all observations in df_prods that include items from departments: alcohol, deli, beverages, and meat/seafood (dinner party items)

# %%
# Recalling department_ids
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
# Creating a subset with dinner party items, department_ids 5, 20, 7, 12
df_dinner_party_items = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
# Checking subset on dinner party items
df_dinner_party_items.head(20)
# Out:
#     product_id                                       product_name  aisle_id  \
# 2            3               Robust Golden Unsweetened Oolong Tea        94
# 6            7                     Pure Coconut Water With Orange        98
# 9           10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10          11                                  Peach Mango Juice        31
# 16          17                                  Rendered Duck Fat        35
# 19          20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22          23                             Organic Turkey Burgers        49
# 34          35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38          39           Daily Tangerine Citrus Flavored Beverage        64
# 39          40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 43          44                        Sparkling Raspberry Seltzer       115
# ...

# %% [markdown]
# ## Step 06.8: Count of rows in df_dinner_party_items

# %%
# Checking dimensions of df_dinner_party_items
df_dinner_party_items.shape
# Out:
# (7650, 5)

# %% [markdown]
# ## Step 06.9: Extracting all information about user with user_id=1

# %%
# Creating a subset for user_id 1
df_user_id_1 = df_ords.loc[df_ords['user_id']=='1']

# %%
# Checking subset for user_id 1
df_user_id_1.head(30)
# Out:
#    order_id user_id  order_sequence_per_user  order_day_of_the_week  \
# 0   2539329       1                        1                      2
# 1   2398795       1                        2                      3
# 2    473747       1                        3                      3
# 3   2254736       1                        4                      4
# 4    431534       1                        5                      4
# 5   3367565       1                        6                      2
# 6    550135       1                        7                      1
# 7   3108588       1                        8                      1
# 8   2295261       1                        9                      1
# 9   2550362       1                       10                      4
# 10  1187899       1                       11                      4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# ...

# %% [markdown]
# ## Step 06.10: Providing details about behaviour of user with user_id=1 (basic stats)

# %%
# Descriptive analysis of df_user_id_1
df_user_id_1.describe()
# Out:
#        order_sequence_per_user  order_day_of_the_week  order_hour_of_day  \
# count                11.000000              11.000000          11.000000
# mean                  6.000000               2.636364          10.090909
# std                   3.316625               1.286291           3.477198
# min                   1.000000               1.000000           7.000000
# 25%                   3.500000               1.500000           7.500000
# 50%                   6.000000               3.000000           8.000000
# 75%                   8.500000               4.000000          13.000000
# max                  11.000000               4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %% [markdown]
# ## Step 06.12: Exporting wrangled df_ords

# %%
df_ords.to_csv(os.path.join(path, '02 Data', '02 Prepared data', 'orders_wrangled.csv'), index=False)

# %% [markdown]
# ## Step 06.13: Exporting wrangled dataframe on departments

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data', '02 Prepared data', 'departments_wrangled.csv'))
